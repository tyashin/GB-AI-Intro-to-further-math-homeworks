# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Задание 17.6.5 - Парабола
xlist = np.linspace(-200.0, 200.0, 1000) 
ylist = np.linspace(-200.0, 200.0, 1000) 
X,Y = np.meshgrid(xlist, ylist)
F = Y**2 - 2*X -2*Y - 5
plt.contour(X, Y, F, [0])
plt.show()

# %%
#Задание 17.6.6 - Эллипс
xlist = np.linspace(-5.0, 5.0, 100) 
ylist = np.linspace(-5.0, 5.0, 100) 
X,Y = np.meshgrid(xlist, ylist)
F = 3*X**2 + 5*Y**2 + 12*X - 30*Y + 42
plt.contour(X, Y, F, [0])
plt.show()

# %%
#Задание 17.6.7 - Гипербола
xlist = np.linspace(-5.0, 5.0, 100) 
ylist = np.linspace(-5.0, 10.0, 100) 
X,Y = np.meshgrid(xlist, ylist)
F = 2*X**2 - Y**2 + 6*Y -7
plt.contour(X, Y, F, [0])
plt.show()

# %%
#Задание 17.6.8 - Гипербола
xlist = np.linspace(-50.0, 50.0, 100) 
ylist = np.linspace(-50.0, 50.0, 100) 
X,Y = np.meshgrid(xlist, ylist)
F = 2*X**2 - 3*Y**2 - 28*X - 42*Y - 55
plt.contour(X, Y, F, [0])
plt.show()
