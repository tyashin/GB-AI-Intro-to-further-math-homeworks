# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Практическое задание по теме “Введение в аналитическую геометрию”

# %% [markdown]
# **1.2. Задание: напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)**

# %%
x = 10
y = 15
print(f'Длина вектора: {np.sqrt(x ** 2 + y ** 2 )}')
# Out:
# Длина вектора: 18.027756377319946

# %% [markdown]
# **3. Задание (в программе):
#   напишите код на Python, реализующий построение графиков:
#   окружности,
#   эллипса,
#   гиперболы.**

# %%
# Окружность
data = np.linspace(0, 2*np.pi, 100)
radius = 1
x = radius*np.cos(data)
y = radius*np.sin(data)
figure, axes = plt.subplots(1)
axes.plot(x, y)
axes.set_aspect(1)
plt.show()

# %%
# Эллипс
a=2.     
b=1.5    
data = np.linspace(0, 2*pi, 100)
plt.plot(a*np.cos(data), b*np.sin(data))
axes.set_aspect(1)
plt.show()

# %%
# Гипербола
xlist = np.linspace(-2.0, 2.0, 100) 
ylist = np.linspace(-2.0, 2.0, 100) 
X,Y = np.meshgrid(xlist, ylist)
F = Y**2/0.1 - X**2/0.05 - 1
plt.contour(X, Y, F, [0])
plt.show()

# %% [markdown]
# **5.1 Задание (в программе): Нарисуйте трехмерный график двух параллельных плоскостей.**

# %%
fig = figure(figsize = (7, 7))
ax = Axes3D(fig)
X = np.arange(-20, 20, 5)
Y = np.arange(-20, 20, 5)
X, Y = np.meshgrid(X, Y)
Z = 10*X + 1000
Z2 = 10*X + 10
ax.plot_wireframe(X, Y, Z, linestyle='--', linewidth=1)
ax.plot_wireframe(X, Y, Z2,linestyle='--', linewidth=1, colors='magenta')
show()

# %% [markdown]
# **5.2 Задание (в программе): Нарисуйте трехмерный график двух любых поверхностей второго порядка.**

# %%
fig = figure(figsize = (7, 7))
ax = Axes3D(fig)
X = np.arange(-20, 20, 1)
Y = np.arange(-20, 20, 1)
X, Y = np.meshgrid(X, Y)
Z = 3*X**2 + 3*Y**2
Z2 = (X**2/0.5 - Y**2/0.2)/2
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z2)
show()

# %% [markdown]
# ## Практическое задание по теме “Графики на плоскости”

# %% [markdown]
# **1.Задание (в программе)
# Нарисуйте график функции: y(x) = k∙cos(x – a) + b для некоторых (2-3 различных) значений параметров k, a, b**

# %%
x = np.linspace(np.pi, 6*np.pi, 300)

k, a, b = np.linspace(10, 20, num = 3)
k1, a1, b1 = np.linspace(20, 30, num = 3)
k2, a2, b2 = np.linspace(40, 50, num = 3)

print(f'k={k}, a={a}, b={b}')
print(f'k1={k1}, a1={a1}, b1={b1}')
print(f'k2={k2}, a2={a2}, b2={b2}')

plt.plot(x, k * np.cos(x - a) + b, color='green',label='k, a, b')
plt.plot(x, k1 * np.cos(x - a1) + b1, color='blue', label='k1, a1, b1')
plt.plot(x, k2 * np.cos(x - a2) + b2, color='magenta', label='k2, a2, b2')

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.style.use('classic')
plt.show()
# Out:
# k=10.0, a=15.0, b=20.0
# k1=20.0, a1=25.0, b1=30.0
# k2=40.0, a2=45.0, b2=50.0

# %% [markdown]
# **3. Задание (в программе)
#      1. Напишите код, который будет переводить полярные координаты в декартовы.**

# %%
def convertPolarToCartesian(radius,angle):
    x = radius*np.cos(angle)
    y = radius*np.sin(angle)
    return (x,y)

print(convertPolarToCartesian(10,np.pi/2))
# Out:
# (6.123233995736766e-16, 10.0)

# %% [markdown]
# **2. Напишите код, который будет рисовать график окружности в полярных
# координатах.**

# %%
angle = np.linspace(0, 2*np.pi, 360)
plt.polar(angle, [5]*len(angle)) 
plt.show()

# %% [markdown]
# **3. Напишите код, который будет рисовать график отрезка прямой линии в
# полярных координатах.**

# %%
radiuses = [5, 10]
angles = [np.pi/4, np.pi*3/4]
plt.polar(angles, radiuses)         
plt.show()
